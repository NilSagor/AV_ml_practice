# %% [markdown]
# import libraries

# %%
# data manipulation
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
#warnings.filterwarnings('igonre')

import datetime
from sklearn.model_selection import train_test_split

# %%
# import data
train =pd.read_csv('datasets/train.csv')
test =pd.read_csv('datasets/test.csv')
view_log =pd.read_csv('datasets/view_log.csv')
item_data =pd.read_csv('datasets/item_data.csv')

# %%
print(train.shape, test.shape, view_log.shape, item_data.shape)
# Out:
# (237609, 7) (90675, 6) (3118622, 5) (132761, 6)

# %%
train.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# 2  intermediate      1         0
# 3        latest      1         0
# 4        latest      0         0

# %%
view_log.head(5)
# Out:
#            server_time device_type  session_id  user_id  item_id
# 0  2018-10-15 08:58:00     android      112333     4557    32970
# 1  2018-10-15 08:58:00     android      503590    74788     7640
# 2  2018-10-15 08:58:00     android      573960    23628   128855
# 3  2018-10-15 08:58:00     android      121691     2430    12774
# 4  2018-10-15 08:58:00     android      218564    19227    28296

# %% [markdown]
# Merging train data

# %%
ite = pd.merge(train,view_log,on="user_id", how="left")

# %%
ite.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 3  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 4  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
#
#   os_version  is_4G  is_click          server_time device_type  session_id  \
# 0        old      0         0  2018-10-19 18:11:00     android      190710
# 1     latest      1         1  2018-10-21 06:13:00     android      356854
# 2     latest      1         1  2018-10-21 06:13:00     android      356854
# 3     latest      1         1  2018-10-21 17:01:00     android      345289
# 4     latest      1         1  2018-10-22 09:54:00     android      406658
#
#    item_id
# 0    43886
# 1    43209
# 2    66370
# ...

# %%
train_data = pd.merge(ite, item_data, on="item_id", how="left")
